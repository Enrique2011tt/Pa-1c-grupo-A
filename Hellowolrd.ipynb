# %% [markdown]
# <a href="https://colab.research.google.com/github/Enrique2011tt/Pa-1c-grupo-A/blob/main/Hellowolrd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritmos

# %%
# Entrada
comprimento = 10
largura = 5

#Processamento

área = comprimento * largura

#Saída

print(f"Total da área: {área}")
# Out:
# Total da área: 50

# %% [markdown]
# Escreva Um algorítmo e o programa que recebe 04 notas do aluno e calcula a média depois mostra a média

# %%
#Entrada
nota_1 = 6
nota_2 = 7
nota_3 = 8
nota_4 = 9

#Processamento
média = (nota_1 + nota_2 + nota_3 + nota_4) /4

#Saída

print(f"Total da média: {média}")
# Out:
# Total da média: 7.5

# %%
#Entrada
numero = 67


#Processamento
dobro = numero * 2


#Saída
print(f"O dobro do número é: {dobro}")
# Out:
# O dobro do número é: 134

# %%
#Fazer um cadastro simples.
#Entrada : nome e idade

#Processamento : armazenar os dados

# Saída :  Mensagem de boas vindas


# Entrada

nome = str (input("Digite seu nome: "))
idade = int (input("Digite sua idade: "))

# Processamento

# Saída

print (f'Olá {nome}, seja bem vindo!')
print (f"Você tem {idade} anos. ")
# Out:
# Digite seu nome: dadad
# Digite sua idade: 12
# Olá dadad, seja bem vindo!
# Você tem 12 anos.

# %% [markdown]
# Fazer um programa que converte a temperatura de
# Celsius para Fahrenheit.
#
# Entrada : graus celsius
#
# Processamento : converter a temperatura para Fahrenheit.
#
# Saída : Mostrar a temperatura em fahrenheit
#
# F = (C x 9/5) + 32

# %%
C = float(input("Digite a temperatura em Celsius:  "))
F = (C * 9/5) +32
print(f"A temperatura em Fahrenheit é: {F}")
# Out:
# Digite a temperatura em Celsius:  67
# A temperatura em Fahrenheit é: 152.6

# %%
from __future__ import division
from re import sub
# Operadores aritméticos



# Soma de dois números

a = int (input("digite o primeiro número: "))
b = int (input("digite o segundo número: "))

soma = a+b
sub  = a-b
mult = a*b
division = a/b
resto = a % b #resto da divisão



print (f"a mult de {a} vezes {b} é igual a: {mult}")
print (f"a sub de {a} menos {b} é igual a: {sub}")
print (f" A soma de {a} mais {b} é igual a: {soma} ")
print (f" A division de {a} dividido {b} é igual a: {division}")
print (f" O resto da divisão de {a} por {b} é igual a: {resto}")

print('-----------Soma-----------')
print("")
print()
# Out:
# digite o primeiro número: 5
# digite o segundo número: 5
# a mult de 5 vezes 5 é igual a: 25
# a sub de 5 menos 5 é igual a: 0
#  A soma de 5 mais 5 é igual a: 10
#  A division de 5 dividido 5 é igual a: 1.0
#  O resto da divisão de 5 por 5 é igual a: 0
# -----------Soma-----------

# %%
num1 = int(input("digite um número: "))
num2 = int(input("digite outro número: "))

igual = num1 == num2
diferente = num1 != num2
maior = num1 > num2
menor = num1 < num2
menorigual = num1 <= num2
maiorigual = num1 >= num2
print(igual)
print(maior)
print(menor)
print(menorigual)
print(maiorigual)
print(diferente)
# Out:
# digite um número: 67
# digite outro número: 67
# True
# False
# False
# True
# True
# False
